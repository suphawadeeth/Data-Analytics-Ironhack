# %% [markdown]
# ## 1.05 Activity 1
# Refer to the file files_for_activities/merged_clean_ver1.csv for this exercise.

# %%
import pandas as pd

# %%
# Import the merged_clean_ver1.csv file.

df = pd.read_csv("/Users/kt/Desktop/Ironhack/Data-Analytics-Ironhack/unit-1/week-2/data_1.05_activities/merged_clean_ver1.csv")

# %%
# Check the data types of all columns in the dataframe.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3993 entries, 0 to 3992
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               3993 non-null   int64
#  1   id                       3993 non-null   int64
#  2   state                    3993 non-null   object
#  3   gender                   3993 non-null   object
#  4   median_home_val          3993 non-null   float64
#  5   median_household_income  3993 non-null   int64
#  6   ic2                      3993 non-null   float64
#  7   ic3                      3993 non-null   int64
#  8   ic4                      3993 non-null   float64
#  9   ic5                      3993 non-null   float64
#  10  avggift                  3993 non-null   float64
#  11  target_d                 3993 non-null   float64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 374.5+ KB

# %%
# Use the describe method on only the float type columns.
df1 = df[["median_home_val", "ic2", "ic4", "ic5", "avggift", "target_d"]]
df1.describe()
# Out:
#        median_home_val          ic2          ic4            ic5      avggift  \
# count      3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean       1158.437751   400.713248   444.732031   16456.413724    11.785117
# std        1033.485773   180.568500   175.004178    9455.318118    10.172672
# min           0.000000     0.000000     0.000000       0.000000     2.260870
# 25%         548.000000   284.000000   325.000000   11136.000000     7.187500
# 50%         803.000000   366.000000   410.000000   14356.000000    10.000000
# 75%        1349.000000   478.000000   528.000000   18780.000000    14.428571
# max        5982.000000  1500.000000  1331.000000  174523.000000   450.000000
#
#           target_d
# count  3993.000000
# mean     15.665036
# std      12.703041
# min       1.000000
# 25%      10.000000
# 50%      14.000000
# 75%      20.000000
# max     200.000000

# %%
len(df1)
# Out:
# 3993

# %%
# Debate
# What is the difference between population mean and sample mean.
df1.sample(10).mean()
# Out:
# median_home_val      887.300000
# ic2                  371.700000
# ic4                  419.400000
# ic5                14732.100000
# avggift               10.449989
# target_d              10.800000
# dtype: float64

# %% [markdown]
# ## Population mean

# %%
# Population mean is calculated by the whole population/whole dataset
# In this case for example, dataset is 3993 individual data (rows).
# Population mean is calculated from 3993 rows.

df1.mean()
# Out:
# median_home_val     1158.437751
# ic2                  400.713248
# ic4                  444.732031
# ic5                16456.413724
# avggift               11.785117
# target_d              15.665036
# dtype: float64

# %% [markdown]
# ## Sample mean

# %% [markdown]
# Sample mean is calculated by random set/group of data in that population (dataset).
#
# Since we grab only some amount of data to describe the whole population, this is only mean "assumption"/"prediction".
#
#
# That means, if the sample is bad (e.g. sample is picked from one side of the distribution especially if that population is not normal distributed or sample size is too small and it might not be good enough to represent the whole population)
#
# In the real world, the bigger sample size the closer to reality.

# %%
# In this case for example, dataset is 3993 individual data (rows).

# If we (randomly) pick only 10 out of 3993
# mean value will be much more differ comparing to mean of the population
# And if we calculate this set of sample (size=10) many times, we'll see that the mean are strong varied (high standard deviation)

df1.sample(10).mean()
# Out:
# median_home_val     1335.300000
# ic2                  499.900000
# ic4                  532.500000
# ic5                18836.300000
# avggift               14.453492
# target_d              18.300000
# dtype: float64

# %%
# but if we increase the size to 100
# the mean has less standard deviation but still not close to reality (whole population)
df1.sample(100).mean()
# Out:
# median_home_val     1332.890000
# ic2                  420.060000
# ic4                  470.010000
# ic5                17903.230000
# avggift               12.018736
# target_d              14.830000
# dtype: float64

# %%
# size of 1000 is a bit better than 100 
# but much better than the sample size of 10 and closer to population mean

df1.sample(1000).mean()
# Out:
# median_home_val     1212.334876
# ic2                  409.893000
# ic4                  453.129000
# ic5                17012.949000
# avggift               12.026117
# target_d              16.052750
# dtype: float64

# %% [markdown]
# ## 1.05 Activity 2
# (Keep working on the same file.)

# %%
# Get the numeric data.
df2 = df.select_dtypes(include="number")
df2.sample(10)
# Out:
#       Unnamed: 0      id  median_home_val  median_household_income    ic2  \
# 3477         485  130530            698.0                      377  395.0
# 2994           2  101388            526.0                      340  348.0
# 3810         818   60490            874.0                      510  516.0
# 3623         631   70835            354.0                      207  234.0
# 413          416   20438            509.0                      248  254.0
# 355          358  169973           1514.0                      325  451.0
# 1433         441   68240            237.0                      255  250.0
# 3741         749  107693            259.0                      265  311.0
# 744          747   73504            460.0                      237  279.0
# 3856         864   39869           2171.0                      545  613.0
#
#       ic3    ic4      ic5    avggift  target_d
# 3477  382  407.0  13327.0  20.000000      20.0
# 2994  321  342.0   9687.0   5.800000      10.0
# ...

# %%
# Use the describe() method on the numeric data in the DataFrame.
df2.describe()
# Out:
#         Unnamed: 0             id  median_home_val  median_household_income  \
# count  3993.000000    3993.000000      3993.000000              3993.000000
# mean    499.431255   98929.308039      1158.437751               351.622840
# std     288.332533   58179.839090      1033.485773               168.488445
# min       0.000000      12.000000         0.000000                 0.000000
# 25%     250.000000   46153.000000       548.000000               239.000000
# 50%     499.000000  101432.000000       803.000000               318.000000
# 75%     749.000000  151653.000000      1349.000000               425.000000
# max    1001.000000  191779.000000      5982.000000              1500.000000
#
#                ic2          ic3          ic4            ic5      avggift  \
# count  3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean    400.713248   399.876283   444.732031   16456.413724    11.785117
# ...

# %%
# Print the median.
df2.median()
# Out:
# Unnamed: 0                    499.0
# id                         101432.0
# median_home_val               803.0
# median_household_income       318.0
# ic2                           366.0
# ic3                           365.0
# ic4                           410.0
# ic5                         14356.0
# avggift                        10.0
# target_d                       14.0
# dtype: float64

# %%
# Print IQR.
from scipy import stats

iqr = stats.iqr(df2, interpolation = "midpoint")
iqr
# Out:
# 729.0

# %%
# Or use numpy
import numpy as np

# define Q1 & Q3
q1, q3 = np.percentile(df2, [25,75])

# calculate interquatile range
inter_q = q3 - q1

# display IQR
inter_q
# Out:
# 729.0

# %% [markdown]
# ## 1.05 Activity 3
# Refer to the file files_for_activities/merged_clean_ver2.csv for this exercise.

# %%
# Load data from the merged_clean_ver2.csv file.

df3 = pd.read_csv("/Users/kt/Desktop/Ironhack/Data-Analytics-Ironhack/unit-1/week-2/data_1.05_activities/merged_clean_ver2.csv")

# %%
df3 = df3.drop("Unnamed: 0", axis=1) #drop unwanted column
df3.head()
# Out:
#        id state  gender  median_home_val  median_household_income    ic2  ic3  \
# 0   44060    FL    Male      1158.437751                      392  430.0  466
# 1   96093    IL    Male       537.000000                      365  415.0  410
# 2   43333    FL  Female       725.000000                      301  340.0  361
# 3   21885    NC    Male      1158.437751                      401  407.0  399
# 4  190108    FL  Female       995.000000                      252  280.0  316
#
#      ic4      ic5    avggift  target_d      ic2_
# 0  520.0  21975.0  28.000000     100.0  Moderate
# 1  473.0  19387.0   5.666667       7.0  Moderate
# 2  436.0  18837.0   4.111111       5.0       Low
# 3  413.0  14014.0  27.277778      38.0  Moderate
# 4  348.0  17991.0   6.000000       5.0       Low

# %%
df3.corr().round(2) # see correlation with ['target_d']
# Out:
#                            id  median_home_val  median_household_income   ic2  \
# id                       1.00             0.25                     0.10  0.09
# median_home_val          0.25             1.00                     0.71  0.74
# median_household_income  0.10             0.71                     1.00  0.95
# ic2                      0.09             0.74                     0.95  1.00
# ic3                      0.11             0.73                     0.97  0.95
# ic4                      0.10             0.75                     0.93  0.97
# ic5                      0.07             0.75                     0.81  0.87
# avggift                 -0.00             0.14                     0.12  0.14
# target_d                 0.03             0.12                     0.11  0.13
#
#                           ic3   ic4   ic5  avggift  target_d
# id                       0.11  0.10  0.07    -0.00      0.03
# median_home_val          0.73  0.75  0.75     0.14      0.12
# ...

# %% [markdown]
# ### Plot Pearson Correlation Heatmap.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Pearson Correlation Heatmap.

corr_data = df3.select_dtypes([np.number])
correlations_matrix = corr_data.corr(method='pearson')  
correlations_matrix.round(2)
# Out:
#                            id  median_home_val  median_household_income   ic2  \
# id                       1.00             0.25                     0.10  0.09
# median_home_val          0.25             1.00                     0.71  0.74
# median_household_income  0.10             0.71                     1.00  0.95
# ic2                      0.09             0.74                     0.95  1.00
# ic3                      0.11             0.73                     0.97  0.95
# ic4                      0.10             0.75                     0.93  0.97
# ic5                      0.07             0.75                     0.81  0.87
# avggift                 -0.00             0.14                     0.12  0.14
# target_d                 0.03             0.12                     0.11  0.13
#
#                           ic3   ic4   ic5  avggift  target_d
# id                       0.11  0.10  0.07    -0.00      0.03
# median_home_val          0.73  0.75  0.75     0.14      0.12
# ...

# %%
mask = np.zeros_like(correlations_matrix)

mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True, cmap='RdPu')
plt.show()

# %% [markdown]
# ### Plot Spearman Correlation Heatmap.

# %%
# Plot Spearman Correlation Heatmap.

corr_spearman = df3.select_dtypes([np.number])
corr_spearman_matrix = corr_spearman.corr(method='spearman')  # method='spearman'

mask = np.zeros_like(correlations_matrix)

mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(corr_spearman_matrix, mask=mask, annot=True, cmap='YlOrRd')
plt.show()

# %% [markdown]
# ### Plot Kendall Correlation Heatmap.

# %%
# Plot Kendall Correlation Heatmap.

corr_kendall = df3.select_dtypes([np.number])
corr_kendall_matrix = corr_kendall.corr(method='kendall')  # method='spearman'

mask = np.zeros_like(correlations_matrix)

mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(corr_kendall_matrix, mask=mask, annot=True, cmap='PuBuGn')
plt.show()

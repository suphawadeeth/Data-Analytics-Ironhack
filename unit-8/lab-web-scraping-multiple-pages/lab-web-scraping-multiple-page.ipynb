# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# <h4>Please scroll down to Lab | Web Scraping Multiple Pages</h4>
#
#
# </div>

# %% [markdown]
# # Lab | Web Scraping Single Page
# ### Business goal:
# - Check the case_study_gnod.md file.
#
# - Make sure you've understood the big picture of your project:
#
#     - the goal of the company (Gnod),
#     - their current product (Gnoosic),
#     - their strategy, and
#     - how your project fits into this context.
#
#     Re-read the business case and the e-mail from the CTO, take a look at the flowchart and create an initial Trello board with the tasks you think you'll have to accomplish.
#
# ### Instructions - Scraping popular songs
# - Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputted song, but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
#
# - You have find data on the internet about currently popular songs. Billboard maintains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100.
#
# - It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# <h1>Objective of this lab:</h1>
#
#
# <h5> - Get top 100 songs on Billboard, list into a pandas dataframe</h5>
# </div>

# %% [markdown]
# # Import libraries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from urllib.request import urlopen
import re

# %% [markdown]
# # Scrapping the content from the web

# %%
# open url and read the whole url page
html = urlopen("https://www.billboard.com/charts/hot-100").read()

# Parsing the data into a readable form & assign into a "soup" object
soup = BeautifulSoup(html, "html.parser")

# %%
# Retrieve all the h3 tag

tag = soup("h3")
# tag

# %%
# Class for all the song in the top 100 songs except the top1
class_100 = "c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"

# Class for the top 1 song
class_1 = "c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet"

# %%
# Set a list for collecting song title
title = []

# %%
# Retrieve the top 1 song
song_1 = soup.find_all("h3", attrs={"class": class_1})

# Get the name of the song
title_1 = song_1[0].get_text()

# Append the top 1 song into the list
title.append(title_1)
title
# Out:
# ['\n\n\t\n\t\n\t\t\n\t\t\t\t\tLast Night\t\t\n\t\n']

# %%
# Retrieve the top 100 song (except the top1)
song_100 = soup.find_all("h3", attrs={"class": class_100})

# Get the name of the song for all songs in this class_100 & append in the same list above
for i in range(len(song_100)):
    title.append(song_100[i].get_text())

# %%
# Check the list
# title

# %% [markdown]
# - We see all the whitespace pattern before and after the title (string)
# - Remove them using regex

# %%
# Regex for finding all whitespace & other unicode characters
pattern = re.compile("^\s+$")

# Iterates through the list "title" 
# and strip() removes/trims all the the whitespace from string and put it into a list []
title = [item.strip() for item in title if not pattern.match(item)]
# title

# %% [markdown]
# #### What does the script above do?
#
# - Note: Need a little explanation for myself
#
# **Regular Expression**:
#
#    ^ --> start with
#
#    \s --> matches a whitespace (blank, tab \t, and newline \r or \n)
#
#    "+" --> one or more
#
#    $ --> end of string
#
#
# ---
# \s
# For Unicode (str) patterns:
# Matches Unicode whitespace characters (which includes [ \t\n\r\f\v], and also many other characters, for example the non-breaking spaces mandated by typography rules in many languages). If the ASCII flag is used, only [ \t\n\r\f\v] is matched.
#
# For 8-bit (bytes) patterns:
# Matches characters considered whitespace in the ASCII character set; this is equivalent to [ \t\n\r\f\v].
#
# - [Ref](https://docs.python.org/3/library/re.html): https://docs.python.org/3/library/re.html
# ---
#
#
#
#
#
# #### For Loop:
# **[item.strip() for item in title if not regex.match(item)]**
#
# - It iterates through the list "title" and strip() removes all the the white space from string and put it into a  list []
#
#
# - The loop can be written (in the way that easy to understand) as follow:
#
# ```
# for item in title:
#     if not pattern.match(item):
#         title.append(item.strip())
#
# ```
#
#
# ##### Some functions:
#
# - match() - to find the match string and return the first occurence
# - [re.compile()](https://pynative.com/python-regex-compile/) - method is used to compile a regular expression pattern provided as a string into a regex pattern object

# %% [markdown]
# ## Get Artists Name

# %%
# Retrieve all the span tag

span_tage = soup("span")
# span_tage

# %%
# We'll get artist name in these classes
class_artist_1 = "c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"

class_artist_100 = "c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"

# %%
# Set a list for collecting artist 
artist = []

# Retrieve the top 1 artist
artist_1 = soup.find_all("span", attrs={"class": class_artist_1})

# Get the name of the artist
artist_name_1 = artist_1[0].get_text()

# Append the top 1 artist into the list
artist.append(artist_name_1)
artist
# Out:
# ['\n\t\n\tMorgan Wallen\n']

# %%
# Retrieve the top 100 song (except the top1)
artist_100 = soup.find_all("span", attrs={"class": class_artist_100})

# Get the name of the song for all songs in this class_100 & append in the same list above
for j in range(len(artist_100)):
    artist.append(artist_100[j].get_text())

# Check the list
# artist

# %%
# Remove \n\t characters
artist = [name.strip() for name in artist if not pattern.match(name)]
# artist

# %% [markdown]
# # Billboard Hot 100

# %%
# Put data into a pandas dataframe
df = pd.DataFrame({"Song": title, "Artist": artist})
df
# Out:
#                 Song                         Artist
# 0         Last Night                  Morgan Wallen
# 1            Flowers                    Miley Cyrus
# 2           Fast Car                     Luke Combs
# 3          Calm Down            Rema & Selena Gomez
# 4        All My Life     Lil Durk Featuring J. Cole
# ..               ...                            ...
# 95           Save Me  Jelly Roll With Lainey Wilson
# 96        Yandel 150                  Yandel & Feid
# 97              Beso       Rosalia & Rauw Alejandro
# 98  I Wrote The Book                  Morgan Wallen
# 99       Hummingbird     Metro Boomin & James Blake
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Sources:
# #### About requests.get()
#    - [GET and POST Requests Using Python](https://www.geeksforgeeks.org/get-post-requests-using-python/)
#    - [Python requests: GET Request Explained](https://datagy.io/python-requests-get-request/)
#    - [Python Requests get() Method](https://www.w3schools.com/python/ref_requests_get.asp)
#
#
# #### Web Scrapping
#    - [BeautifulSoup Guide: Scraping HTML Pages With Python](https://scrapeops.io/python-web-scraping-playbook/python-beautifulsoup-web-scraping/)
#
#
# #### Regular Express Cheat Sheet
#    - [RegEX cheatsheet](https://quickref.me/regex.html)
#    - [re.compile()](https://pynative.com/python-regex-compile/) - method is used to compile a regular expression pattern provided as a string into a regex pattern object
#    - [Removing \n\t from string](https://stackoverflow.com/questions/47953523/remove-an-n-t-t-t-element-from-list)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <h1>Lab | Web Scraping Multiple Pages</h1>
#
# <h3>Objective of this lab:</h3>
#
#
# <h5> - Get more songs from different sources and list them into the same pandas dataframe from previous lab</h5>
# </div>

# %% [markdown]
# ### Instructions
# Prioritize the MVP
# In the previous lab, you had to scrape data about "hot songs". It's critical to be on track with that part, as it was part of the request from the CTO.
#
# If you couldn't finish the first lab, use this time to go back there.
#
# ### Expand the project
# If you're done, you can try to expand the project on your own. Here are a few suggestions:
#
# - Find other lists of hot songs on the internet and scrape them too: having a bigger pool of songs will be awesome!
# - Apply the same logic to other "groups" of songs: the best songs from a decade or from a country / culture / language / genre.
# - Wikipedia maintains a large collection of lists of songs: https://en.wikipedia.org/wiki/Lists_of_songs
#
# ### Practice web scraping
# As you've seen, scraping the internet is a skill that can get you all sorts of information. Here are some little challenges that you can try to gain more experience in the field:
#
#
# - Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'
# - Find the number of titles that have changed in the United States Code since its last release point: url = 'http://uscode.house.gov/download/download.shtml'
# - Create a Python list with the top ten FBI's Most Wanted names: url = 'https://www.fbi.gov/wanted/topten'
# - Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe: url = 'https://www.emsc-csem.org/Earthquake/'
# - List all language names and number of related articles in the order they appear in wikipedia.org: url = 'https://www.wikipedia.org/'
# - A list with the different kind of datasets available in data.gov.uk: url = 'https://data.gov.uk/'
# - Display the top 10 languages by number of native speakers stored in a pandas dataframe: url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
import requests as r

# Send a request to a web page

youtube = r.get("https://charts.youtube.com/charts/TopSongs/global")
spotify = r.get("https://kworb.net/spotify/country/global_weekly_totals.html")
itunes = r.get("https://kworb.net/ww/")
apple = r.get("https://kworb.net/apple_songs/")
rollingstone = r.get("https://www.rollingstone.com/music/music-lists/best-songs-of-2023-so-far-1234766821/")

# %%
# Return the status code after sending request

web = {"youtube": youtube, "spotify": spotify, "itunes": itunes, "apple": apple, "rollingstone": rollingstone}
for k, v in web.items():
    print(k, "status:", v.status_code)
# Out:
# youtube status: 200
# spotify status: 200
# itunes status: 200
# apple status: 200
# rollingstone status: 200

# %% [markdown]
# - Status-code 200: Everything went okay and the result has been returned (if any)

# %%
# Parsing the data into a readable form
yt = BeautifulSoup(youtube.content, "html.parser")
sptf = BeautifulSoup(spotify.content, "html.parser") 
itun = BeautifulSoup(itunes.content, "html.parser")
appl = BeautifulSoup(apple.content, "html.parser")
rlst = BeautifulSoup(rollingstone.content, "html.parser")

# %% [markdown]
#  - I went over all the webs above. I can't retrieve data from youtube and rollingstone.
#  - For the time I have, I decided to do one web from above which is itun (& the song list is similar to apple).
#  - And I also do multiple page from npr.com (see script below)

# %% [markdown]
# # Itunes

# %%
# Find all song title & artist in the list
itun_200 = itun.find_all('td', attrs={"class": "mp text"})

# %%
# Put them in a list
itun_list = []
for i in range(len(itun_200)):
    itun_list.append(itun_200[i].get_text())

# itun_list

# %%
# Separate song title from artist name
a = []
itun_title = []
itun_artist = []

for j in range(len(itun_list)):
    a.append(itun_list[j].split(" - "))

for element in a:
    itun_title.append(element[1])
    itun_artist.append(element[0])

# %%
# Put song list into a dataframe
itun_df = pd.DataFrame({"Song": itun_title, "Artist": itun_artist})
itun_df.head()
print("Total", len(itun_df), "songs")
# Out:
# Total 200 songs

# %%
# Pool all songs in one dataframe (billboard + itunes)
df = pd.concat([df, itun_df])
print("Total", len(df), "songs")
# Out:
# Total 300 songs

# %% [markdown]
# # NPR (multiple page)

# %%
import time

# time.sleep(15)
html_lst = []
npr_list = []
pages = [1, 2, 3, 4, 5]
digit = [2083, 2978, 3422, 3900, 4266]

for (di, page) in zip(digit, pages):
    npr_req_get = r.get(f'https://www.npr.org/2022/12/15/113580{di}/100-best-songs-2022-page-{page}')
    npr_soup = BeautifulSoup(npr_req_get.content, 'html.parser')
    songs = npr_soup.find_all('h3', attrs={"class": "edTag"})
    html_lst.append(songs)
    
    for m in range(len(songs)):
        npr_list.append(songs[m].get_text())

    time.sleep(15)

html_lst
# Out:
# [[<h3 class="edTag">Little Simz</h3>,
#   <h3 class="edTag">"Gorilla"<em> </em></h3>,
#   <h3 class="edTag">Ian William Craig</h3>,
#   <h3 class="edTag">"Attention For It Radiates"</h3>,
#   <h3 class="edTag">Viking Ding Dong x Ravi B</h3>,
#   <h3 class="edTag">"Leave It Alone (Remix)"</h3>,
#   <h3 class="edTag">Adeem the Artist</h3>,
#   <h3 class="edTag">"Middle of a Heart"<em> </em></h3>,
#   <h3 class="edTag">Zahsosaa, D STURDY &amp; DJ Crazy</h3>,
#   <h3 class="edTag">"Shakedhat"</h3>,
#   <h3 class="edTag">Gabriels</h3>,
#   <h3 class="edTag">"If You Only Knew"</h3>,
#   <h3 class="edTag">DOMi &amp; JD BECK</h3>,
#   <h3 class="edTag">"SMiLE"</h3>,
#   <h3 class="edTag">Rema</h3>,
#   <h3 class="edTag">"Calm Down"</h3>,
#   <h3 class="edTag">Pigeon Pit</h3>,
#   <h3 class="edTag">"milk crates"</h3>,
#   <h3 class="edTag">Tyler Childers</h3>,
#   <h3 class="edTag">"Angel Band (Jubilee Version)"</h3>,
#   <h3 class="edTag">Straw Man Army</h3>,
#   <h3 class="edTag">"Human Kind"</h3>,
#   <h3 class="edTag">Guitarricadelafuente</h3>,
#   <h3 class="edTag">"Quien encendió la luz"</h3>,
#   <h3 class="edTag">Mary Halvorson</h3>,
#   <h3 class="edTag">"Night Shift"</h3>,
#   <h3 class="edTag">Leyla McCalla</h3>,
#   <h3 class="edTag">"Dodinin"</h3>,
#   <h3 class="edTag">The Mountain Goats</h3>,
#   <h3 class="edTag">"Bleed Out"</h3>,
#   <h3 class="edTag">NewJeans</h3>,
#   <h3 class="edTag">"Hype Boy"</h3>,
#   <h3 class="edTag">Joyce</h3>,
#   <h3 class="edTag">"Feminina"</h3>,
#   <h3 class="edTag">Ayra Starr</h3>,
#   <h3 class="edTag">"Rush"</h3>,
#   <h3 class="edTag">Disclosure feat. RAYE</h3>,
#   <h3 class="edTag">"Waterfall"</h3>,
#   <h3 class="edTag">Ari Lennox</h3>,
#   <h3 class="edTag">"POF"</h3>,
#   <h3 class="edTag"><a href="https://www.npr.org/2022/12/15/1135802978/100-best-songs-2022-page-2">Next &gt;</a></h3>],
#  [<h3 class="edTag">The 1975</h3>,
#   <h3 class="edTag">"Part of the Band"</h3>,
#   <h3 class="edTag">Anna Tivel</h3>,
#   <h3 class="edTag">"Black Umbrella"</h3>,
#   <h3 class="edTag">Caroline Shaw &amp; Attacca Quartet</h3>,
#   <h3 class="edTag">"First Essay (Nimrod)"</h3>,
#   <h3 class="edTag">Beth Orton</h3>,
#   <h3 class="edTag">"Friday Night"</h3>,
#   <h3 class="edTag">DJ Python</h3>,
#   <h3 class="edTag">"Angel"</h3>,
#   <h3 class="edTag">Patricia Brennan</h3>,
#   <h3 class="edTag">"Unquiet Respect"</h3>,
#   <h3 class="edTag">Black Sherif</h3>,
#   <h3 class="edTag">"Kwaku the Traveller"</h3>,
#   <h3 class="edTag">Madison Cunningham</h3>,
#   <h3 class="edTag">"Life According To Raechel"</h3>,
#   <h3 class="edTag">La Doña</h3>,
#   <h3 class="edTag">"Penas Con Pan"</h3>,
#   <h3 class="edTag">Julia Jacklin</h3>,
#   <h3 class="edTag">"Love, Try Not To Let Go"</h3>,
#   <h3 class="edTag">Molly Tuttle &amp; Golden Highway</h3>,
#   <h3 class="edTag">"Crooked Tree"</h3>,
#   <h3 class="edTag">Black Country, New Road</h3>,
#   <h3 class="edTag">"The Place Where He Inserted the Blade"</h3>,
#   <h3 class="edTag">Khruangbin &amp; Leon Bridges</h3>,
#   <h3 class="edTag">"B-Side"</h3>,
#   <h3 class="edTag">Nduduzo Makhathini</h3>,
#   <h3 class="edTag">"Unonkanyamba"</h3>,
#   <h3 class="edTag">KAROL G</h3>,
#   <h3 class="edTag">"PROVENZA"</h3>,
#   <h3 class="edTag">Vince Staples</h3>,
#   <h3 class="edTag">"When Sparks Fly"</h3>,
#   <h3 class="edTag">Tove Lo</h3>,
#   <h3 class="edTag">"2 Die 4"</h3>,
#   <h3 class="edTag">Jazmine Sullivan</h3>,
#   <h3 class="edTag">"BPW"</h3>,
#   <h3 class="edTag">Denzel Curry</h3>,
#   <h3 class="edTag">"Walkin"</h3>,
#   <h3 class="edTag">beabadoobee</h3>,
#   <h3 class="edTag">"Talk"</h3>,
#   <h3 class="edTag"><a href="https://www.npr.org//2022/12/15/1135803422/100-best-songs-2022-page-3">Next &gt;</a></h3>],
#  [<h3 class="edTag">Björk</h3>,
#   <h3 class="edTag">"Atopos"</h3>,
#   <h3 class="edTag">Hyd</h3>,
#   <h3 class="edTag">"Afar"</h3>,
#   <h3 class="edTag">Sky Ferreira</h3>,
#   <h3 class="edTag">"Don't Forget"</h3>,
#   <h3 class="edTag">Regina Spektor</h3>,
#   <h3 class="edTag">"Up The Mountain"</h3>,
#   <h3 class="edTag">Tommy McLain feat. Elvis Costello</h3>,
#   <h3 class="edTag">"I Ran Down Every Dream"</h3>,
#   <h3 class="edTag">Yahritza y Su Esencia</h3>,
#   <h3 class="edTag">"Estas En Mi Pasado"</h3>,
#   <h3 class="edTag">Víkingur Ólafsson</h3>,
#   <h3 class="edTag">Schumann: "Study in Canonic Form, Op. 56, No. 1"</h3>,
#   <h3 class="edTag">Lil Yachty</h3>,
#   <h3 class="edTag">"Poland"</h3>,
#   <h3 class="edTag">LF System</h3>,
#   <h3 class="edTag">"Afraid to Feel"</h3>,
#   <h3 class="edTag">Soccer Mommy</h3>,
#   <h3 class="edTag">"Shotgun"</h3>,
#   <h3 class="edTag">LE SSERAFIM</h3>,
#   <h3 class="edTag">"Antifragile"</h3>,
#   <h3 class="edTag">Flo Milli</h3>,
#   <h3 class="edTag">"Bed Time"</h3>,
#   <h3 class="edTag">Kendrick Lamar</h3>,
#   <h3 class="edTag">"The Heart Part 5"</h3>,
#   <h3 class="edTag">Sudan Archives</h3>,
#   <h3 class="edTag">"Home Maker"</h3>,
#   <h3 class="edTag">Fly Anakin</h3>,
#   <h3 class="edTag">"Love Song (Come Back)"</h3>,
#   <h3 class="edTag">Julius Rodriguez</h3>,
#   <h3 class="edTag">"Dora's Lullaby"</h3>,
#   <h3 class="edTag">Maggie Rogers</h3>,
#   <h3 class="edTag">"That's Where I Am"</h3>,
#   <h3 class="edTag">Rico Nasty</h3>,
#   <h3 class="edTag">"Gotsta Get Paid"</h3>,
#   <h3 class="edTag">Anna Butterss</h3>,
#   <h3 class="edTag">"Doo Wop"</h3>,
#   <h3 class="edTag">Sean Shibe</h3>,
#   <h3 class="edTag">"Peace Piece"</h3>,
#   <h3 class="edTag"><a href="https://www.npr.org/2022/12/15/1135803900/100-best-songs-2022-page-4">Next &gt;</a></h3>],
#  [<h3 class="edTag">Syd feat. Lucky Daye </h3>,
#   <h3 class="edTag">"CYBAH"</h3>,
#   <h3 class="edTag">Ice Spice</h3>,
#   <h3 class="edTag">"Munch (Feelin' U)"</h3>,
#   <h3 class="edTag">Joy Orbison x Overmono feat. ABRA </h3>,
#   <h3 class="edTag">"Blind Date"</h3>,
#   <h3 class="edTag">NxWorries feat. H.E.R. </h3>,
#   <h3 class="edTag">"Where I Go"</h3>,
#   <h3 class="edTag">Joan Shelley feat. Bill Callahan</h3>,
#   <h3 class="edTag">"Amberlit Morning"</h3>,
#   <h3 class="edTag">Doechii</h3>,
#   <h3 class="edTag">"Crazy"</h3>,
#   <h3 class="edTag">Julia Bullock</h3>,
#   <h3 class="edTag">"One by One"</h3>,
#   <h3 class="edTag">Taylor Swift</h3>,
#   <h3 class="edTag">"Anti-Hero"</h3>,
#   <h3 class="edTag">Hikaru Utada</h3>,
#   <h3 class="edTag">"BAD MODE"</h3>,
#   <h3 class="edTag">Koffee</h3>,
#   <h3 class="edTag">"Pull Up"</h3>,
#   <h3 class="edTag">SiR feat. Scribz Riley</h3>,
#   <h3 class="edTag">"Life is Good"</h3>,
#   <h3 class="edTag">Hermanos Gutiérrez</h3>,
#   <h3 class="edTag">"El Bueno y El Malo"</h3>,
#   <h3 class="edTag">Porridge Radio</h3>,
#   <h3 class="edTag">"Back To The Radio"</h3>,
#   <h3 class="edTag">Kevin Morby</h3>,
#   <h3 class="edTag">"This is a Photograph"</h3>,
#   <h3 class="edTag">Makaya McCraven</h3>,
#   <h3 class="edTag">"Dream Another"</h3>,
#   <h3 class="edTag">Ethel Cain</h3>,
#   <h3 class="edTag">"American Teenager"</h3>,
#   <h3 class="edTag">Megan Thee Stallion</h3>,
#   <h3 class="edTag">"Plan B"</h3>,
#   <h3 class="edTag">The Beths</h3>,
#   <h3 class="edTag">"Expert in a Dying Field"</h3>,
#   <h3 class="edTag">Let's Eat Grandma</h3>,
#   <h3 class="edTag">"Happy New Year"</h3>,
#   <h3 class="edTag">Omar Apollo</h3>,
#   <h3 class="edTag">"Tamagotchi"</h3>,
#   <h3 class="edTag"><a href="https://npr.org/2022/12/15/1135804266/100-best-songs-2022-page-5">Next &gt;</a></h3>],
#  [<h3 class="edTag">Molly Nilsson</h3>,
#   <h3 class="edTag">"Pompeii"<em> </em></h3>,
#   <h3 class="edTag">Third Coast Percussion</h3>,
#   <h3 class="edTag">"Derivative"</h3>,
#   <h3 class="edTag">Plains</h3>,
#   <h3 class="edTag">"Abilene"</h3>,
#   <h3 class="edTag">Fireboy DML &amp; Asake</h3>,
#   <h3 class="edTag">"Bandana"</h3>,
#   <h3 class="edTag">Lizzo</h3>,
#   <h3 class="edTag">"About Damn Time"<em> </em></h3>,
#   <h3 class="edTag">SZA</h3>,
#   <h3 class="edTag">"Shirt"<em> </em></h3>,
#   <h3 class="edTag">Zach Bryan</h3>,
#   <h3 class="edTag">"Something in the Orange"</h3>,
#   <h3 class="edTag">Fontaines D.C.</h3>,
#   <h3 class="edTag">"Jackie Down the Line"<em> </em></h3>,
#   <h3 class="edTag">Harry Styles</h3>,
#   <h3 class="edTag">"As It Was"<em> </em></h3>,
#   <h3 class="edTag">Stromae</h3>,
#   <h3 class="edTag">"L'enfer"<em> </em></h3>,
#   <h3 class="edTag">Steve Lacy</h3>,
#   <h3 class="edTag">"Bad Habit"</h3>,
#   <h3 class="edTag">Joyce Wrice x KAYTRANADA</h3>,
#   <h3 class="edTag">"Iced Tea"<em> </em></h3>,
#   <h3 class="edTag">MUNA</h3>,
#   <h3 class="edTag">"What I Want"<em> </em></h3>,
#   <h3 class="edTag">Paramore</h3>,
#   <h3 class="edTag">"This is Why"<em> </em></h3>,
#   <h3 class="edTag">Gunna &amp; Future feat. Young Thug</h3>,
#   <h3 class="edTag">"pushin P"</h3>,
#   <h3 class="edTag">ROSALÍA</h3>,
#   <h3 class="edTag">"SAOKO"<em> </em></h3>,
#   <h3 class="edTag">Alex G</h3>,
#   <h3 class="edTag">"Runner"<em> </em></h3>,
#   <h3 class="edTag">Bad Bunny</h3>,
#   <h3 class="edTag">"El Apagón"</h3>,
#   <h3 class="edTag">Beyoncé</h3>,
#   <h3 class="edTag">"ALIEN SUPERSTAR"</h3>,
#   <h3 class="edTag">Hitkidd &amp; GloRilla</h3>,
#   <h3 class="edTag">"F.N.F. (Let's Go)"</h3>]]

# %%
npr_list
# Out:
# ['Little Simz',
#  '"Gorilla" ',
#  'Ian William Craig',
#  '"Attention For It Radiates"',
#  'Viking Ding Dong x Ravi B',
#  '"Leave It Alone (Remix)"',
#  'Adeem the Artist',
#  '"Middle of a Heart" ',
#  'Zahsosaa, D STURDY & DJ Crazy',
#  '"Shakedhat"',
#  'Gabriels',
#  '"If You Only Knew"',
#  'DOMi & JD BECK',
#  '"SMiLE"',
#  'Rema',
#  '"Calm Down"',
#  'Pigeon Pit',
#  '"milk crates"',
#  'Tyler Childers',
#  '"Angel Band (Jubilee Version)"',
#  'Straw Man Army',
#  '"Human Kind"',
#  'Guitarricadelafuente',
#  '"Quien encendió la luz"',
#  'Mary Halvorson',
#  '"Night Shift"',
#  'Leyla McCalla',
#  '"Dodinin"',
#  'The Mountain Goats',
#  '"Bleed Out"',
#  'NewJeans',
#  '"Hype Boy"',
#  'Joyce',
#  '"Feminina"',
#  'Ayra Starr',
#  '"Rush"',
#  'Disclosure feat. RAYE',
#  '"Waterfall"',
#  'Ari Lennox',
#  '"POF"',
#  'Next >',
#  'The 1975',
#  '"Part of the Band"',
#  'Anna Tivel',
#  '"Black Umbrella"',
#  'Caroline Shaw & Attacca Quartet',
#  '"First Essay (Nimrod)"',
#  'Beth Orton',
#  '"Friday Night"',
#  'DJ Python',
#  '"Angel"',
#  'Patricia Brennan',
#  '"Unquiet Respect"',
#  'Black Sherif',
#  '"Kwaku the Traveller"',
#  'Madison Cunningham',
#  '"Life According To Raechel"',
#  'La Doña',
#  '"Penas Con Pan"',
#  'Julia Jacklin',
#  '"Love, Try Not To Let Go"',
#  'Molly Tuttle & Golden Highway',
#  '"Crooked Tree"',
#  'Black Country, New Road',
#  '"The Place Where He Inserted the Blade"',
#  'Khruangbin & Leon Bridges',
#  '"B-Side"',
#  'Nduduzo Makhathini',
#  '"Unonkanyamba"',
#  'KAROL G',
#  '"PROVENZA"',
#  'Vince Staples',
#  '"When Sparks Fly"',
#  'Tove Lo',
#  '"2 Die 4"',
#  'Jazmine Sullivan',
#  '"BPW"',
#  'Denzel Curry',
#  '"Walkin"',
#  'beabadoobee',
#  '"Talk"',
#  'Next >',
#  'Björk',
#  '"Atopos"',
#  'Hyd',
#  '"Afar"',
#  'Sky Ferreira',
#  '"Don\'t Forget"',
#  'Regina Spektor',
#  '"Up The Mountain"',
#  'Tommy McLain feat. Elvis Costello',
#  '"I Ran Down Every Dream"',
#  'Yahritza y Su Esencia',
#  '"Estas En Mi Pasado"',
#  'Víkingur Ólafsson',
#  'Schumann: "Study in Canonic Form, Op. 56, No. 1"',
#  'Lil Yachty',
#  '"Poland"',
#  'LF System',
#  '"Afraid to Feel"',
#  'Soccer Mommy',
#  '"Shotgun"',
#  'LE SSERAFIM',
#  '"Antifragile"',
#  'Flo Milli',
#  '"Bed Time"',
#  'Kendrick Lamar',
#  '"The Heart Part 5"',
#  'Sudan Archives',
#  '"Home Maker"',
#  'Fly Anakin',
#  '"Love Song (Come Back)"',
#  'Julius Rodriguez',
#  '"Dora\'s Lullaby"',
#  'Maggie Rogers',
#  '"That\'s Where I Am"',
#  'Rico Nasty',
#  '"Gotsta Get Paid"',
#  'Anna Butterss',
#  '"Doo Wop"',
#  'Sean Shibe',
#  '"Peace Piece"',
#  'Next >',
#  'Syd feat. Lucky Daye ',
#  '"CYBAH"',
#  'Ice Spice',
#  '"Munch (Feelin\' U)"',
#  'Joy Orbison x Overmono feat. ABRA ',
#  '"Blind Date"',
#  'NxWorries feat. H.E.R. ',
#  '"Where I Go"',
#  'Joan Shelley feat. Bill Callahan',
#  '"Amberlit Morning"',
#  'Doechii',
#  '"Crazy"',
#  'Julia Bullock',
#  '"One by One"',
#  'Taylor Swift',
#  '"Anti-Hero"',
#  'Hikaru Utada',
#  '"BAD MODE"',
#  'Koffee',
#  '"Pull Up"',
#  'SiR feat. Scribz Riley',
#  '"Life is Good"',
#  'Hermanos Gutiérrez',
#  '"El Bueno y El Malo"',
#  'Porridge Radio',
#  '"Back To The Radio"',
#  'Kevin Morby',
#  '"This is a Photograph"',
#  'Makaya McCraven',
#  '"Dream Another"',
#  'Ethel Cain',
#  '"American Teenager"',
#  'Megan Thee Stallion',
#  '"Plan B"',
#  'The Beths',
#  '"Expert in a Dying Field"',
#  "Let's Eat Grandma",
#  '"Happy New Year"',
#  'Omar Apollo',
#  '"Tamagotchi"',
#  'Next >',
#  'Molly Nilsson',
#  '"Pompeii" ',
#  'Third Coast Percussion',
#  '"Derivative"',
#  'Plains',
#  '"Abilene"',
#  'Fireboy DML & Asake',
#  '"Bandana"',
#  'Lizzo',
#  '"About Damn Time" ',
#  'SZA',
#  '"Shirt" ',
#  'Zach Bryan',
#  '"Something in the Orange"',
#  'Fontaines D.C.',
#  '"Jackie Down the Line" ',
#  'Harry Styles',
#  '"As It Was" ',
#  'Stromae',
#  '"L\'enfer" ',
#  'Steve Lacy',
#  '"Bad Habit"',
#  'Joyce Wrice x KAYTRANADA',
#  '"Iced Tea" ',
#  'MUNA',
#  '"What I Want" ',
#  'Paramore',
#  '"This is Why" ',
#  'Gunna & Future feat. Young Thug',
#  '"pushin P"',
#  'ROSALÍA',
#  '"SAOKO" ',
#  'Alex G',
#  '"Runner" ',
#  'Bad Bunny',
#  '"El Apagón"',
#  'Beyoncé',
#  '"ALIEN SUPERSTAR"',
#  'Hitkidd & GloRilla',
#  '"F.N.F. (Let\'s Go)"']

# %%
# Separate song title and artist into different lists
npr_artist = []
npr_title = []

for q in range(0, len(npr_list)):
    if q % 2:
        npr_title.append(npr_list[q])
    else:
        npr_artist.append(npr_list[q])

# %%
# Remove some characters from song title list
npr_correct_title = []
for ti in range(len(npr_title)):
    npr_correct_title.append(npr_title[ti].strip('"').replace('" ', ''))

# Remove some characters from artist list
npr_correct_artist = []
for ar in range(len(npr_artist)):
    npr_correct_artist.append(npr_artist[ar].strip('"').replace('" ', ''))

# %%
npr_df = pd.DataFrame({"Song": npr_correct_title, "Artist": npr_correct_artist})
npr_df
# Out:
#                           Song                         Artist
# 0                      Gorilla                    Little Simz
# 1    Attention For It Radiates              Ian William Craig
# 2       Leave It Alone (Remix)      Viking Ding Dong x Ravi B
# 3            Middle of a Heart               Adeem the Artist
# 4                    Shakedhat  Zahsosaa, D STURDY & DJ Crazy
# ..                         ...                            ...
# 97                       SAOKO                        ROSALÍA
# 98                      Runner                         Alex G
# 99                   El Apagón                      Bad Bunny
# 100            ALIEN SUPERSTAR                        Beyoncé
# 101          F.N.F. (Let's Go)             Hitkidd & GloRilla
#
# [102 rows x 2 columns]

# %% [markdown]
# - There are 2 extra rows
# - How can I find out which of them are not song?

# %%
pd.set_option('display.max_rows', None)

# %%
npr_df
# Out:
#                                                 Song  \
# 0                                            Gorilla
# 1                          Attention For It Radiates
# 2                             Leave It Alone (Remix)
# 3                                  Middle of a Heart
# 4                                          Shakedhat
# 5                                   If You Only Knew
# 6                                              SMiLE
# 7                                          Calm Down
# 8                                        milk crates
# 9                       Angel Band (Jubilee Version)
# 10                                        Human Kind
# 11                             Quien encendió la luz
# 12                                       Night Shift
# 13                                           Dodinin
# 14                                         Bleed Out
# 15                                          Hype Boy
# 16                                          Feminina
# 17                                              Rush
# 18                                         Waterfall
# 19                                               POF
# 20                                          The 1975
# 21                                        Anna Tivel
# 22                   Caroline Shaw & Attacca Quartet
# 23                                        Beth Orton
# 24                                         DJ Python
# 25                                  Patricia Brennan
# 26                                      Black Sherif
# 27                                Madison Cunningham
# 28                                           La Doña
# 29                                     Julia Jacklin
# 30                     Molly Tuttle & Golden Highway
# 31                           Black Country, New Road
# 32                         Khruangbin & Leon Bridges
# 33                                Nduduzo Makhathini
# 34                                           KAROL G
# 35                                     Vince Staples
# 36                                           Tove Lo
# 37                                  Jazmine Sullivan
# 38                                      Denzel Curry
# 39                                       beabadoobee
# 40                                            Next >
# 41                                            Atopos
# 42                                              Afar
# 43                                      Don't Forget
# 44                                   Up The Mountain
# 45                            I Ran Down Every Dream
# 46                                Estas En Mi Pasado
# 47   Schumann: "Study in Canonic Form, Op. 56, No. 1
# 48                                            Poland
# 49                                    Afraid to Feel
# 50                                           Shotgun
# 51                                       Antifragile
# 52                                          Bed Time
# 53                                  The Heart Part 5
# 54                                        Home Maker
# 55                             Love Song (Come Back)
# 56                                    Dora's Lullaby
# 57                                 That's Where I Am
# 58                                   Gotsta Get Paid
# 59                                           Doo Wop
# 60                                       Peace Piece
# 61                             Syd feat. Lucky Daye
# 62                                         Ice Spice
# 63                Joy Orbison x Overmono feat. ABRA
# 64                           NxWorries feat. H.E.R.
# 65                  Joan Shelley feat. Bill Callahan
# 66                                           Doechii
# 67                                     Julia Bullock
# 68                                      Taylor Swift
# 69                                      Hikaru Utada
# 70                                            Koffee
# 71                            SiR feat. Scribz Riley
# 72                                Hermanos Gutiérrez
# 73                                    Porridge Radio
# 74                                       Kevin Morby
# 75                                   Makaya McCraven
# 76                                        Ethel Cain
# 77                               Megan Thee Stallion
# 78                                         The Beths
# 79                                 Let's Eat Grandma
# 80                                       Omar Apollo
# 81                                            Next >
# 82                                           Pompeii
# 83                                        Derivative
# 84                                           Abilene
# 85                                           Bandana
# 86                                   About Damn Time
# 87                                             Shirt
# 88                           Something in the Orange
# 89                              Jackie Down the Line
# 90                                         As It Was
# 91                                           L'enfer
# 92                                         Bad Habit
# 93                                          Iced Tea
# 94                                       What I Want
# 95                                       This is Why
# 96                                          pushin P
# 97                                             SAOKO
# 98                                            Runner
# 99                                         El Apagón
# 100                                  ALIEN SUPERSTAR
# 101                                F.N.F. (Let's Go)
#
#                                     Artist
# 0                              Little Simz
# 1                        Ian William Craig
# 2                Viking Ding Dong x Ravi B
# 3                         Adeem the Artist
# 4            Zahsosaa, D STURDY & DJ Crazy
# 5                                 Gabriels
# 6                           DOMi & JD BECK
# 7                                     Rema
# 8                               Pigeon Pit
# 9                           Tyler Childers
# 10                          Straw Man Army
# 11                    Guitarricadelafuente
# 12                          Mary Halvorson
# 13                           Leyla McCalla
# 14                      The Mountain Goats
# 15                                NewJeans
# 16                                   Joyce
# 17                              Ayra Starr
# 18                   Disclosure feat. RAYE
# 19                              Ari Lennox
# 20                                  Next >
# 21                        Part of the Band
# 22                          Black Umbrella
# 23                    First Essay (Nimrod)
# 24                            Friday Night
# 25                                   Angel
# 26                         Unquiet Respect
# 27                     Kwaku the Traveller
# 28               Life According To Raechel
# 29                           Penas Con Pan
# 30                 Love, Try Not To Let Go
# 31                            Crooked Tree
# 32   The Place Where He Inserted the Blade
# 33                                  B-Side
# 34                            Unonkanyamba
# 35                                PROVENZA
# 36                         When Sparks Fly
# 37                                 2 Die 4
# 38                                     BPW
# 39                                  Walkin
# 40                                    Talk
# 41                                   Björk
# 42                                     Hyd
# 43                            Sky Ferreira
# 44                          Regina Spektor
# 45       Tommy McLain feat. Elvis Costello
# 46                   Yahritza y Su Esencia
# 47                       Víkingur Ólafsson
# 48                              Lil Yachty
# 49                               LF System
# 50                            Soccer Mommy
# 51                             LE SSERAFIM
# 52                               Flo Milli
# 53                          Kendrick Lamar
# 54                          Sudan Archives
# 55                              Fly Anakin
# 56                        Julius Rodriguez
# 57                           Maggie Rogers
# 58                              Rico Nasty
# 59                           Anna Butterss
# 60                              Sean Shibe
# 61                                  Next >
# 62                                   CYBAH
# 63                       Munch (Feelin' U)
# 64                              Blind Date
# 65                              Where I Go
# 66                        Amberlit Morning
# 67                                   Crazy
# 68                              One by One
# 69                               Anti-Hero
# 70                                BAD MODE
# 71                                 Pull Up
# 72                            Life is Good
# 73                      El Bueno y El Malo
# 74                       Back To The Radio
# 75                    This is a Photograph
# 76                           Dream Another
# 77                       American Teenager
# 78                                  Plan B
# 79                 Expert in a Dying Field
# 80                          Happy New Year
# 81                              Tamagotchi
# 82                           Molly Nilsson
# 83                  Third Coast Percussion
# 84                                  Plains
# 85                     Fireboy DML & Asake
# 86                                   Lizzo
# 87                                     SZA
# 88                              Zach Bryan
# 89                          Fontaines D.C.
# 90                            Harry Styles
# 91                                 Stromae
# 92                              Steve Lacy
# 93                Joyce Wrice x KAYTRANADA
# 94                                    MUNA
# 95                                Paramore
# 96         Gunna & Future feat. Young Thug
# 97                                 ROSALÍA
# 98                                  Alex G
# 99                               Bad Bunny
# 100                                Beyoncé
# 101                     Hitkidd & GloRilla

# %%
# Concat into one dataframe
df = pd.concat([df, npr_df])
print("Total", len(df), "songs")
# Out:
# Total 402 songs

# %% [markdown]
# ### Next step
# - Check for duplication song
#
# ### Note
# - I learned later that we have .get_text(strip=True) function to get cleaned, nice string. We don't need extra work for that.
